# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'


from skimage import data
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
refFilename = "form.jpg"
print("Reading reference image : ", refFilename)
im2 = cv2.imread(refFilename, cv2.IMREAD_COLOR)

plt.imshow(im2)
# Out:
# Reading reference image :  form.jpg

# %%
# Read image to be aligned
imFilename = "scanned-form.jpg"
print("Reading image to align : ", imFilename);  
im1 = cv2.imread(imFilename, cv2.IMREAD_COLOR)

plt.imshow(im1)
# Out:
# Reading image to align :  scanned-form.jpg

# %%
# Here I have some pre-computed key points. You need to figure out how to do in assignment by yourself


points1 = np.load("points1.npy")
points2 = np.load("points2.npy")
points1

# points1 = points1
# points2 = points2[:5]
print(points1.shape)
# Out:
# (30, 2)

# %%
# Find homography
h, mask = cv2.findHomography(points1, points2, cv2.RANSAC)

# Use homography
height, width, channels = im2.shape
im1Reg = cv2.warpPerspective(im1, h, (width, height))

# %%
plt.imshow(im1Reg)
